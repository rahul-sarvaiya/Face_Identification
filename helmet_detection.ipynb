# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)
model.train(data="data.yaml",epochs=100)
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 6.23M/6.23M [00:02<00:00, 2.54MB/s]
# Ultralytics YOLOv8.0.59  Python-3.7.16 torch-1.13.1+cpu CPU
# ...

# %%
# !yolo task = detect mode=val model="C:/Data_s/cnn_prj/runs/detect/train2/weights/best.pt" data=data.yaml
# Out:
# Ultralytics YOLOv8.0.59  Python-3.7.16 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# val: Scanning C:\Data_s\cnn_prj\val\labels.cache... 6 images, 0 backgrounds, 0 corrupt: 100%|##########| 6/6 [00:00<?, ?it/s]
# val: Scanning C:\Data_s\cnn_prj\val\labels.cache... 6 images, 0 backgrounds, 0 corrupt: 100%|##########| 6/6 [00:00<?, ?it/s]
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|##########| 1/1 [00:12<00:00, 12.72s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|##########| 1/1 [00:12<00:00, 12.72s/it]
#                    all          6         11      0.785      0.823      0.913      0.564
#                class_0          6          8      0.913          1      0.995       0.64
# ...

# %%
# !yolo task = detect mode=predict model="C:/Data_s/cnn_prj/runs/detect/train2/weights/best.pt" conf=0.5 source=helmet.mp4
# Out:
# Ultralytics YOLOv8.0.59  Python-3.7.16 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/1778) C:\Data_s\cnn_prj\helmet.mp4: 384x640 1 class_0, 1 class_1, 226.6ms
# video 1/1 (2/1778) C:\Data_s\cnn_prj\helmet.mp4: 384x640 2 class_0s, 2 class_1s, 210.1ms
# video 1/1 (3/1778) C:\Data_s\cnn_prj\helmet.mp4: 384x640 2 class_0s, 2 class_1s, 225.4ms
# video 1/1 (4/1778) C:\Data_s\cnn_prj\helmet.mp4: 384x640 3 class_0s, 3 class_1s, 206.6ms
# video 1/1 (5/1778) C:\Data_s\cnn_prj\helmet.mp4: 384x640 3 class_0s, 3 class_1s, 192.9ms
# video 1/1 (6/1778) C:\Data_s\cnn_prj\helmet.mp4: 384x640 2 class_0s, 3 class_1s, 195.5ms
# video 1/1 (7/1778) C:\Data_s\cnn_prj\helmet.mp4: 384x640 2 class_0s, 3 class_1s, 193.4ms
# video 1/1 (8/1778) C:\Data_s\cnn_prj\helmet.mp4: 384x640 3 class_0s, 3 class_1s, 194.6ms
# video 1/1 (9/1778) C:\Data_s\cnn_prj\helmet.mp4: 384x640 3 class_0s, 3 class_1s, 205.6ms
# ...

# %%
# !yolo task = detect mode=predict model="C:/Data_s/cnn_prj/runs/detect/train2/weights/best.pt" conf=0.5 source=helmet.mp4 show = True save = True
# Out:
# ^C

# %%
# !yolo task = detect mode=predict model="C:/Data_s/cnn_prj/runs/detect/train2/weights/best.pt" conf=0.5 source=test/test_1.jpeg show = True save = True
# Out:
# Ultralytics YOLOv8.0.59  Python-3.7.16 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 C:\Data_s\cnn_prj\test\test_1.jpeg: 448x640 3 class_0s, 133.3ms
# Speed: 0.0ms preprocess, 133.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict

# %%
# !yolo task = detect mode=predict model="C:/Data_s/cnn_prj/runs/detect/train2/weights/best.pt" conf=0.5 source=test/test_2.jpeg save = True
# Out:
# Ultralytics YOLOv8.0.59  Python-3.7.16 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 C:\Data_s\cnn_prj\test\test_2.jpeg: 640x416 1 class_0, 1 class_1, 292.9ms
# Speed: 1.0ms preprocess, 292.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict2

# %%
# !yolo task = detect mode=export model="C:/Data_s/cnn_prj/runs/detect/train2/weights/best.pt" format = tfjs
# Out:
# ^C

# %%
# !yolo task = detect mode=export model="C:/Data_s/cnn_prj/runs/detect/train2/weights/best.pt" format =
